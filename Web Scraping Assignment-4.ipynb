# %%
import pandas as pd
import selenium
from bs4 import BeautifulSoup
import time
from selenium import webdriver
import requests
import re
from selenium.common.exceptions import NoSuchElementException, StaleElementReferenceException
from selenium.webdriver.support.ui import WebDriverWait

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### 1.Scrape the details of most viewed videos on YouTube from Wikipedia.
# ### Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos
# ### You need to find following details:
# A) Rank
# B) Name
# C) Artist
# D) Upload date
# E) Views

# %%
driver = webdriver.Chrome("chromedriver.exe")

# %%
url = "https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos"
driver.get(url)

# %%
rank = []
name = []
artist = []
date = []
views = []

# %%
try:
    for i in driver.find_elements_by_xpath('//table[@class="wikitable sortable jquery-tablesorter"]//tbody//tr//td[1]')[:30]:
        rank.append(i.text)
except NoSuchElementException:
    rank.append("-")
    
try:
    for i in driver.find_elements_by_xpath('//table[@class="wikitable sortable jquery-tablesorter"]//tbody//tr//td[2]')[:30]:
        name.append(i.text)
except NoSuchElementException:
    name.append("-")
    
try:
    for i in driver.find_elements_by_xpath('//table[@class="wikitable sortable jquery-tablesorter"]//tbody//tr//td[3]')[:30]:
        artist.append(i.text)
except NoSuchElementException:
    artist.append("-")
    
try:
    for i in driver.find_elements_by_xpath('//table[@class="wikitable sortable jquery-tablesorter"]//tbody//tr//td[5]')[:30]:
        date.append(i.text)
except NoSuchElementException:
    date.append("-")
    
try:
    for i in driver.find_elements_by_xpath('//table[@class="wikitable sortable jquery-tablesorter"]//tbody//tr//td[4]')[:30]:
        views.append(i.text)
except NoSuchElementException:
    views.append("-")

# %%
df = pd.DataFrame({'Rank':rank,'Name of Video':name,'Artist':artist,'Date of Upload':date,'Total Views':views})
df
# Out:
#    Rank                                    Name of Video  \
# 0    1.                            "Baby Shark Dance"[3]
# 1    2.                                   "Despacito"[6]
# 2    3.                       "Johny Johny Yes Papa"[12]
# 3    4.                               "Shape of You"[13]
# 4    5.                              "See You Again"[15]
# 5    6.                                  "Bath Song"[20]
# 6    7.  "Learning Colors – Colorful Eggs on a Farm"[21]
# 7    8.   "Masha and the Bear – Recipe for Disaster"[22]
# 8    9.                "Phonics Song with Two Words"[23]
# 9   10.                                "Uptown Funk"[24]
# 10  11.                              "Gangnam Style"[25]
# 11  12.                             "Dame Tu Cosita"[30]
# 12  13.                          "Wheels on the Bus"[31]
# 13  14.                                      "Sugar"[32]
# 14  15.                                       "Roar"[33]
# 15  16.                                      "Sorry"[34]
# 16  17.                             "Counting Stars"[35]
# 17  18.                          "Thinking Out Loud"[36]
# 18  19.                             "Girls Like You"[37]
# 19  20.                                      "Faded"[38]
# 20  21.                                     "Axel F"[39]
# 21  22.                                 "Dark Horse"[40]
# 22  23.                                 "Let Her Go"[41]
# 23  24.                                   "Bailando"[42]
# 24  25.                                    "Lean On"[43]
# 25  26.                               "Shake It Off"[44]
# 26  27.                        "Baa Baa Black Sheep"[45]
# 27  28.                                    "Perfect"[46]
# 28  29.           "Waka Waka (This Time for Africa)"[47]
# 29  30.                                   "Mi Gente"[48]
#
#                                          Artist     Date of Upload Total Views
# 0   Pinkfong Baby Shark - Kids' Songs & Stories      June 17, 2016       10.21
# 1                                    Luis Fonsi   January 12, 2017        7.75
# 2                                   LooLoo Kids    October 8, 2016        6.17
# 3                                    Ed Sheeran   January 30, 2017        5.62
# 4                                   Wiz Khalifa      April 6, 2015        5.42
# 5                    Cocomelon – Nursery Rhymes        May 2, 2018        4.99
# 6                                   Miroshka TV  February 27, 2018        4.56
# 7                                    Get Movies   January 31, 2012        4.48
# 8                                     ChuChu TV      March 6, 2014        4.47
# 9                                   Mark Ronson  November 19, 2014        4.46
# 10                                          Psy      July 15, 2012        4.34
# 11                                    El Chombo      April 5, 2018        3.85
# 12                   Cocomelon – Nursery Rhymes       May 24, 2018        3.68
# 13                                     Maroon 5   January 14, 2015        3.64
# 14                                   Katy Perry  September 5, 2013        3.52
# 15                                Justin Bieber   October 22, 2015        3.51
# 16                                  OneRepublic       May 31, 2013        3.51
# 17                                   Ed Sheeran    October 7, 2014        3.41
# 18                                     Maroon 5       May 31, 2018        3.24
# 19                                  Alan Walker   December 3, 2015        3.23
# 20                                   Crazy Frog      June 16, 2009        3.23
# 21                                   Katy Perry  February 20, 2014        3.22
# 22                                    Passenger      July 25, 2012        3.17
# 23                             Enrique Iglesias     April 11, 2014        3.16
# 24                                  Major Lazer     March 22, 2015        3.16
# 25                                 Taylor Swift    August 18, 2014        3.14
# 26                   Cocomelon – Nursery Rhymes      June 25, 2018        3.13
# 27                                   Ed Sheeran   November 9, 2017        3.09
# 28                                      Shakira       June 4, 2010        3.06
# 29                                     J Balvin      June 29, 2017        3.04

# %% [markdown]
# #### 2. Scrape the details team India’s international fixtures from bcci.tv.
# #### Url = https://www.bcci.tv/.
# #### You need to find following details:
# A) Match title (I.e. 1
# st ODI)
# B) Series
# C) Place
# D) Date
# E) Time
#
# Note: - From bcci.tv home page you have reach to the international fixture page through code.

# %%
driver = webdriver.Chrome("chromedriver.exe")

# %%
url = "https://www.bcci.tv/"
driver.get(url)
time.sleep(2)

driver.find_element_by_xpath('//li[@class="nav-item ml-0"]').click()
time.sleep(3)

driver.find_element_by_xpath('/html/body/div[3]/div[2]/div/div/div/div[2]/div[2]/div/div[3]/div/div[1]').click()
time.sleep(2)

search = driver.find_element_by_xpath('/html/body/div[3]/div[2]/div/div/div/div[2]/div[2]/div/div[3]/div/div[2]/div[6]')
search.click()

# %%
match = []
series = []
place = []
date = []
time = []

# %%
try:
    for i in driver.find_elements_by_xpath('//span[@class="ng-binding"]'):
        match.append(i.text)
except NoSuchElementException:
    match.append("-")
    
try:
    for i in driver.find_elements_by_xpath('//span[@class="matchOrderText ng-binding ng-scope"]'):
        series.append(i.text.split('-')[0])
except NoSuchElementException:
    series.append("-")
    
try:
    for i in driver.find_elements_by_xpath('//span[@class="ng-binding ng-scope"]'):
        place.append(i.text)
except NoSuchElementException:
    place.append("-")
    
try:
    for i in driver.find_elements_by_xpath('//h5[@class="ng-binding"]'):
        date.append(i.text)
except NoSuchElementException:
    date.append("-")
    
try:
    for i in driver.find_elements_by_xpath('//h5[@class="text-right ng-binding"]'):
        time.append(i.text)
except NoSuchElementException:
    time.append("-")

# %%
df = pd.DataFrame({'Match Title':match,'Series':series,'Venue':place,'Date':date,'time':time})
df
# Out:
#                                   Match Title     Series  \
# 0     SRI LANKA TOUR OF INDIA T20 SERIES 2022  1st T20I
# 1     SRI LANKA TOUR OF INDIA T20 SERIES 2022  2nd T20I
# 2     SRI LANKA TOUR OF INDIA T20 SERIES 2022  3rd T20I
# 3    SRI LANKA TOUR OF INDIA TEST SERIES 2022  1st Test
# 4    SRI LANKA TOUR OF INDIA TEST SERIES 2022  2nd Test
# 5  SOUTH AFRICA TOUR OF INDIA T20 SERIES 2022  1st T20I
# 6  SOUTH AFRICA TOUR OF INDIA T20 SERIES 2022  2nd T20I
# 7  SOUTH AFRICA TOUR OF INDIA T20 SERIES 2022  3rd T20I
# 8  SOUTH AFRICA TOUR OF INDIA T20 SERIES 2022  4th T20I
# 9  SOUTH AFRICA TOUR OF INDIA T20 SERIES 2022  5th T20I
#
#                                                Venue         Date  \
# 0  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...  24 FEB 2022
# 1      Himachal Pradesh Cricket Association Stadium,  26 FEB 2022
# 2      Himachal Pradesh Cricket Association Stadium,  27 FEB 2022
# 3      Punjab Cricket Association IS Bindra Stadium,   4 MAR 2022
# 4                             M Chinnaswamy Stadium,  12 MAR 2022
# 5                            MA Chidambaram Stadium,   9 JUN 2022
# 6                             M Chinnaswamy Stadium,  12 JUN 2022
# 7              Vidarbha Cricket Association Stadium,  14 JUN 2022
# 8            Saurashtra Cricket Association Stadium,  17 JUN 2022
# 9                              Arun Jaitley Stadium,  19 JUN 2022
#
#            time
# 0   7:00 PM IST
# 1   7:00 PM IST
# 2   7:00 PM IST
# 3   9:30 AM IST
# 4  12:30 PM IST
# 5   7:30 PM IST
# 6   7:30 PM IST
# 7   7:30 PM IST
# 8   7:30 PM IST
# 9   7:30 PM IST

# %% [markdown]
# ### 3. Scrape the details of selenium exception from guru99.com.
# ### Url = https://www.guru99.com/
# ### You need to find following details:
# A) Name
# B) Description
# Note: - From guru99 home page you have to reach to selenium exception handling page through code.

# %%
driver = webdriver.Chrome("chromedriver.exe")

# %%
url = "https://www.guru99.com/"
driver.get(url)

# %%
search_bar = driver.find_element_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div[1]/div[1]/div[2]/div/div[1]/div/div/div/form/table/tbody/tr/td[1]/div/table/tbody/tr/td[1]/input")
search_bar.send_keys("selenium exception handling")
search_btn = driver.find_element_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div[1]/div[1]/div[2]/div/div[1]/div/div/div/form/table/tbody/tr/td[2]/button")
search_btn.click()
time.sleep(2)

# %%
link = driver.find_element_by_xpath('//div[@class="gsc-expansionArea"]//div//a')
page_links = link.get_attribute("href")

driver.get(page_links)
time.sleep(3)

Name = []
for i in driver.find_elements_by_xpath('//table[@class="table table-striped"]//tr//td[1]')[1:]:
    Name.append(i.text)
    
Description = []
for i in driver.find_elements_by_xpath('//table[@class="table table-striped"]//tr//td[2]')[1:]:
    Description.append(i.text)

# %%
df = pd.DataFrame({'Name':Name,'Description':Description})
df
# Out:
#                                    Name  \
# 0         ElementNotSelectableException
# 1                NoSuchElementException
# 2                  NoSuchFrameException
# 3               NoAlertPresentException
# 4                 NoSuchWindowException
# 5        StaleElementReferenceException
# 6              SessionNotFoundException
# 7                      TimeoutException
# 8                    WebDriverException
# 9             ConnectionClosedException
# 10     ElementClickInterceptedException
# 11      ElementNotInteractableException
# 12             ErrorInResponseException
# 13  ErrorHandler.UnknownServerException
# 14         ImeActivationFailedException
# 15             ImeNotAvailableException
# 16         InsecureCertificateException
# 17             InvalidArgumentException
# 18         InvalidCookieDomainException
# 19          InvalidCoordinatesException
# 20          InvalidElementStateExceptio
# 21            InvalidSessionIdException
# 22       InvalidSwitchToTargetException
# 23                  JavascriptException
# 24                        JsonException
# 25             NoSuchAttributeException
# 26       MoveTargetOutOfBoundsException
# 27               NoSuchContextException
# 28                NoSuchCookieException
# 29                    NotFoundException
# 30          RemoteDriverServerException
# 31                  ScreenshotException
# 32           SessionNotCreatedException
# 33           UnableToSetCookieException
# 34           UnexpectedTagNameException
# 35              UnhandledAlertException
# 36      UnexpectedAlertPresentException
# 37               UnknownMethodException
# 38          UnreachableBrowserException
# 39          UnsupportedCommandException
#
#                                           Description
# 0   This Selenium exception occurs when an element...
# 1   This Exception occurs if an element could not ...
# 2   This Exception occurs if the frame target to b...
# 3   This Exception occurs when you switch to no pr...
# 4   This Exception occurs if the window target to ...
# 5   This Selenium exception occurs happens when th...
# 6   The WebDriver is acting after you quit the bro...
# 7   Thrown when there is not enough time for a com...
# 8   This Exception takes place when the WebDriver ...
# 9   This type of Exception takes place when there ...
# 10  The command may not be completed as the elemen...
# 11  This Selenium exception is thrown when any ele...
# 12  This happens while interacting with the Firefo...
# 13  Exception is used as a placeholder in case if ...
# 14  This expectation will occur when IME engine ac...
# 15    It takes place when IME support is unavailable.
# 16  Navigation made the user agent to hit a certif...
# 17  It occurs when an argument does not belong to ...
# 18  This happens when you try to add a cookie unde...
# 19  This type of Exception matches an interacting ...
# 20  It occurs when command can’t be finished when ...
# 21  This Exception took place when the given sessi...
# 22  This occurs when the frame or window target to...
# 23  This issue occurs while executing JavaScript g...
# 24  It occurs when you afford to get the session w...
# 25  This kind of Exception occurs when the attribu...
# 26  It takes place if the target provided to the A...
# 27           ContextAware does mobile device testing.
# 28  This Exception occurs when no cookie matching ...
# 29  This Exception is a subclass of WebDriverExcep...
# 30  This Selenium exception is thrown when the ser...
# 31            It is not possible to capture a screen.
# 32  It happens when a new session could not be suc...
# 33  This occurs if a driver is unable to set a coo...
# 34  Happens if a support class did not get a web e...
# 35  This expectation occurs when there is an alert...
# 36  It occurs when there is the appearance of an u...
# 37  This Exception happens when the requested comm...
# 38  This Exception occurs only when the browser is...
# 39  This occurs when remote WebDriver does n’t sen...

# %% [markdown]
# ### 4. Scrape the details of State-wise GDP of India from statisticstime.com.
# ### Url = http://statisticstimes.com/
# ### You have to find following details:
# A) Rank
# B) State
# C) GSDP
# D) GSDP
# E) Share
# F) GDP($ billion)
#
# Note: - From statisticstimes home page you have to reach to economy page through code.

# %%
driver= webdriver.Chrome("chromedriver.exe")

# %%
url = "https://www.statisticstimes.com/"
driver.get(url)

# %%
economy = driver.find_element_by_xpath("/html/body/div[2]/div[1]/div[2]/div[2]/button")
economy.click()
india = driver.find_element_by_xpath("/html/body/div[2]/div[1]/div[2]/div[2]/div/a[3]")
india.click()
time.sleep(2)

GDP_india = driver.find_element_by_xpath('/html/body/div[2]/div[2]/div[2]/ul/li[1]/a')
GDP_india.click()
time.sleep(3)

# %%
rank = []
state = []
GSDP = []
GSDP1 = []
share = []
GDP = []

# %%
for i in driver.find_elements_by_xpath('//div[@id="table_id_wrapper"]//tbody//tr//td[1]'):
    rank.append(i.text)
    
for i in driver.find_elements_by_xpath('//div[@id="table_id_wrapper"]//tbody//tr//td[2]'):
    state.append(i.text)
    
for i in driver.find_elements_by_xpath('//div[@id="table_id_wrapper"]//tbody//tr//td[3]'):
    GSDP.append(i.text)
    
for i in driver.find_elements_by_xpath('//div[@id="table_id_wrapper"]//tbody//tr//td[4]'):
    GSDP1.append(i.text)
    
for i in driver.find_elements_by_xpath('//div[@id="table_id_wrapper"]//tbody//tr//td[5]'):
    share.append(i.text)
    
for i in driver.find_elements_by_xpath('//div[@id="table_id_wrapper"]//tbody//tr//td[6]'):
    GDP.append(i.text)

# %%
df = pd.DataFrame({'Rank':rank,'State':state,'GSDP(19-20)':GSDP,'GSDP(18-19)':GSDP1,'Share':share,'GDP':GDP})
df
# Out:
#    Rank                      State GSDP(19-20) GSDP(18-19)   Share      GDP
# 0     1                Maharashtra           -   2,632,792  13.94%  399.921
# 1     2                 Tamil Nadu   1,845,853   1,630,208   8.63%  247.629
# 2     3              Uttar Pradesh   1,687,818   1,584,764   8.39%  240.726
# 3     4                    Gujarat           -   1,502,899   7.96%  228.290
# 4     5                  Karnataka   1,631,977   1,493,127   7.91%  226.806
# 5     6                West Bengal   1,253,832   1,089,898   5.77%  165.556
# 6     7                  Rajasthan   1,020,989     942,586   4.99%  143.179
# 7     8             Andhra Pradesh     972,782     862,957   4.57%  131.083
# 8     9                  Telangana     969,604     861,031   4.56%  130.791
# 9    10             Madhya Pradesh     906,672     809,592   4.29%  122.977
# 10   11                     Kerala           -     781,653   4.14%  118.733
# 11   12                      Delhi     856,112     774,870   4.10%  117.703
# 12   13                    Haryana     831,610     734,163   3.89%  111.519
# 13   14                      Bihar     611,804     530,363   2.81%   80.562
# 14   15                     Punjab     574,760     526,376   2.79%   79.957
# 15   16                     Odisha     521,275     487,805   2.58%   74.098
# 16   17                      Assam           -     315,881   1.67%   47.982
# 17   18               Chhattisgarh     329,180     304,063   1.61%   46.187
# 18   19                  Jharkhand     328,598     297,204   1.57%   45.145
# 19   20                Uttarakhand           -     245,895   1.30%   37.351
# 20   21            Jammu & Kashmir           -     155,956   0.83%   23.690
# 21   22           Himachal Pradesh     165,472     153,845   0.81%   23.369
# 22   23                        Goa      80,449      73,170   0.39%   11.115
# 23   24                    Tripura      55,984      49,845   0.26%    7.571
# 24   25                 Chandigarh           -      42,114   0.22%    6.397
# 25   26                 Puducherry      38,253      34,433   0.18%    5.230
# 26   27                  Meghalaya      36,572      33,481   0.18%    5.086
# 27   28                     Sikkim      32,496      28,723   0.15%    4.363
# 28   29                    Manipur      31,790      27,870   0.15%    4.233
# 29   30                   Nagaland           -      27,283   0.14%    4.144
# 30   31          Arunachal Pradesh           -      24,603   0.13%    3.737
# 31   32                    Mizoram      26,503      22,287   0.12%    3.385
# 32   33  Andaman & Nicobar Islands           -           -       -        -

# %% [markdown]
# ## 5. Scrape the details of trending repositories on Github.com.
# ### Url = https://github.com/
# ### You have to find the following details:
# A) Repository title
# B) Repository description
# C) Contributors count
# D) Language used
#
# Note: - From the home page you have to click on the trending option from Explore menu through code.

# %%
driver = webdriver.Chrome("chromedriver.exe")

# %%
url = "https://github.com/"
driver.get(url)

# %%
explore = driver.find_element_by_xpath('/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/summary')
explore.click()
time.sleep(2)

trending = driver.find_element_by_xpath('/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/div/ul/li[5]/a')
trending.click()
time.sleep(2)

# %%
URLs = []
title = []
description = []
count = []
lang = []
language = []

# %%
repository = driver.find_elements_by_xpath("//h1[@class = 'h3 lh-condensed']//a")
for i in repository:
    URLs.append(i.get_attribute("href"))

    

titles = driver.find_elements_by_xpath("//h1[@class = 'h3 lh-condensed']")
for i in titles:
    title.append(i.text)

    

for i in URLs:
    driver.get(i)
    time.sleep(3)
    
    
    
    try:
        desc = driver.find_element_by_xpath("//p[@class='f4 my-3']")
        description.append(desc.text)
    except NoSuchElementException:
        description.append('-')
        
        
    
    try:
        contributor = driver.find_element_by_xpath("//*[contains(text(),'    Contributors ')]")
        count.append(contributor.text.replace('Contributors',''))
    except NoSuchElementException:
        count.append('-')
        
        
    
    try:
        for i in driver.find_elements_by_xpath("//span[@class='color-fg-default text-bold mr-1']"):
            lang.append(i.text)
        language.append(lang)
    except NoSuchElementException:
        language.append('-')

# %%
df = pd.DataFrame({'Repository Title':title,'Repository Description':description,'Contributors Count':count,'Language Used':language})
df
# Out:
#                                      Repository Title  \
# 0                              Anduin2017 / HowToCook
# 1               veeral-patel / how-to-secure-anything
# 2   riti2409 / Resources-for-preparation-Of-Placem...
# 3                           skywind3000 / preserve-cd
# 4                               nusr / hacker-laws-zh
# 5                                    kaist-cp / cs431
# 6                         riti2409 / Operating_System
# 7                   danistefanovic / build-your-own-x
# 8                      ant-design / ant-design-mobile
# 9              GrowingGit / GitHub-Chinese-Top-Charts
# 10                                  apache / superset
# 11                                 FederatedAI / FATE
# 12                                       YaoApp / yao
# 13                            hasura / graphql-engine
# 14                                zellij-org / zellij
# 15                                   facebook / folly
# 16      evilbuffer / malware-and-exploitdev-resources
# 17                                mastodon / mastodon
# 18                                    zadam / trilium
# 19                               jrouwe / JoltPhysics
# 20                       positive-security / find-you
# 21                              influxdata / influxdb
# 22                         midisec / BypassAnti-Virus
# 23               coding-horror / basic-computer-games
# 24                     labuladong / fucking-algorithm
#
#                                Repository Description Contributors Count  \
# 0   程序员在家做饭方法指南。Programmer's guide about how to co...                136
# 1   How to systematically secure anything: a repos...                  5
# 2   Lecture video links for preparation of Placements                  6
# 3                           Game Preservation Project                  2
# 4   💻📖对开发人员有用的定律、理论、原则和模式。(Laws, Theories, Princip...                  9
# 5                                                   -                  9
# 6      Resources , Notes , Videos of Operating System                  -
# 7           🤓 Build your own (insert technology here)                 72
# 8   Essential UI blocks for building mobile web apps.                166
# 9   🇨🇳 GitHub中文排行榜，各语言分离设置「软件 / 资料」榜单，精准定位中文好项目。各取...                  -
# 10  Apache Superset is a Data Visualization and Da...                738
# 11   An Industrial Grade Federated Learning Framework                 62
# 12  Yao A low code engine to create web services a...                  2
# 13  Blazing fast, instant realtime GraphQL APIs on...                416
# 14       A terminal workspace with batteries included                 54
# 15  An open-source C++ library developed and used ...                639
# 16                                                  -                  -
# 17  Your self-hosted, globally interconnected micr...                659
# 18  Build your personal knowledge base with Triliu...                 58
# 19  A multi core friendly rigid body physics and c...                  4
# 20  A stealth AirTag clone that bypasses all of Ap...                  -
# 21  Scalable datastore for metrics, events, and re...                428
# 22                                      免杀姿势学习、记录、复现。                  -
# 23  An updated version of the classic "Basic Compu...                159
# 24  刷算法全靠套路，认准 labuladong 就够了！English version supp...                 97
#
#                                         Language Used
# 0   [Rust, Shell, TypeScript, Less, Other, Java, T...
# 1   [Rust, Shell, TypeScript, Less, Other, Java, T...
# 2   [Rust, Shell, TypeScript, Less, Other, Java, T...
# 3   [Rust, Shell, TypeScript, Less, Other, Java, T...
# 4   [Rust, Shell, TypeScript, Less, Other, Java, T...
# 5   [Rust, Shell, TypeScript, Less, Other, Java, T...
# 6   [Rust, Shell, TypeScript, Less, Other, Java, T...
# 7   [Rust, Shell, TypeScript, Less, Other, Java, T...
# 8   [Rust, Shell, TypeScript, Less, Other, Java, T...
# 9   [Rust, Shell, TypeScript, Less, Other, Java, T...
# 10  [Rust, Shell, TypeScript, Less, Other, Java, T...
# 11  [Rust, Shell, TypeScript, Less, Other, Java, T...
# 12  [Rust, Shell, TypeScript, Less, Other, Java, T...
# 13  [Rust, Shell, TypeScript, Less, Other, Java, T...
# 14  [Rust, Shell, TypeScript, Less, Other, Java, T...
# 15  [Rust, Shell, TypeScript, Less, Other, Java, T...
# 16  [Rust, Shell, TypeScript, Less, Other, Java, T...
# 17  [Rust, Shell, TypeScript, Less, Other, Java, T...
# 18  [Rust, Shell, TypeScript, Less, Other, Java, T...
# 19  [Rust, Shell, TypeScript, Less, Other, Java, T...
# 20  [Rust, Shell, TypeScript, Less, Other, Java, T...
# 21  [Rust, Shell, TypeScript, Less, Other, Java, T...
# 22  [Rust, Shell, TypeScript, Less, Other, Java, T...
# 23  [Rust, Shell, TypeScript, Less, Other, Java, T...
# 24  [Rust, Shell, TypeScript, Less, Other, Java, T...

# %% [markdown]
# ### 6. Scrape the details of top 100 songs on billiboard.com.
# ### Url = https:/www.billboard.com/
# ### You have to find the following details:
# A) Song name
# B) Artist name
# C) Last week rank
# D) Peak rank
# E) Weeks on board
#
# Note: - From the home page you have to click on the charts option then hot 100-page link through code

# %%
driver = webdriver.Chrome("chromedriver.exe")

# %%
url = "https://www.billboard.com/"
driver.get(url)

# %%
charts= driver.find_element_by_xpath("/html/body/div[4]/header/div[1]/div/div/div[2]/div/nav/ul/li[1]/a")
charts.click()

# %%
view = driver.find_element_by_xpath("/html/body/div[4]/main/div[2]/div[1]/div[1]/div/div/div[3]/a")
view.click()

# %%
song = []
artist = []
last = []
peak = []
weeks = []

# %%
for i in driver.find_elements_by_xpath('//div[@class="o-chart-results-list-row-container"]//ul//li//ul//li[1]/h3'):
    song.append(i.text)
    
for i in driver.find_elements_by_xpath('//div[@class="o-chart-results-list-row-container"]//ul//li//ul//li[1]/span'):
    artist.append(i.text)
    
for i in driver.find_elements_by_xpath('//div[@class="o-chart-results-list-row-container"]//ul//li//ul//li[4]/span'):
    last.append(i.text)
    
for i in driver.find_elements_by_xpath('//div[@class="o-chart-results-list-row-container"]//ul//li//ul//li[5]/span'):
    peak.append(i.text)
    
for i in driver.find_elements_by_xpath('//div[@class="o-chart-results-list-row-container"]//ul//li//ul//li[6]/span'):
    weeks.append(i.text)

# %%
print(len(artist),len(song),len(last),len(peak),len(weeks))
# Out:
# 100 100 200 200 100

# %%
billboard = pd.DataFrame({'Song Name':song,'Artist Name':artist,'Last Week Rank':last[:100],'Peak Rank':peak[:100],'Weeks on Board':weeks})
billboard
# Out:
#                           Song Name  \
# 0         We Don't Talk About Bruno
# 1                        Heat Waves
# 2                        Easy On Me
# 3                           abcdefu
# 4                              Stay
# ..                              ...
# 95  All Too Well (Taylor's Version)
# 96       Come Back As A Country Boy
# 97                             Iffy
# 98                       Home Sweet
# 99                         Too Easy
#
#                                           Artist Name Last Week Rank  \
# 0   Carolina Gaitan, Mauro Castillo, Adassa, Rhenz...              1
# 1                                       Glass Animals
# 2                                               Adele              4
# 3                                               GAYLE
# 4                       The Kid LAROI & Justin Bieber              3
# ..                                                ...            ...
# 95                                       Taylor Swift
# 96                                      Blake Shelton             34
# 97                                        Chris Brown
# 98                                  Russell Dickerson             41
# 99                                     Gunna & Future
#
#    Peak Rank Weeks on Board
# 0          1              8
# 1                        57
# 2          2             19
# 3                        13
# 4          1             32
# ..       ...            ...
# 95                       14
# 96        19              5
# 97                        5
# 98        36              5
# 99                       16
#
# [100 rows x 5 columns]

# %% [markdown]
# ### 7. Scrape the details of Data science recruiters from naukri.com.
# ### Url = https://www.naukri.com/
# ### You have to find the following details:
# A) Name
# B) Designation
# C) Company
# D) Skills they hire for
# E) Location
#
# Note: - From naukri.com homepage click on the recruiters option and the on the search pane type Data science and
# click on search. All this should be done through code

# %%
driver = webdriver.Chrome("chromedriver.exe")

# %%
url = "https://www.naukri.com/"
driver.get(url)

# %%
recruiter = driver.find_element_by_xpath("//a[@title='Search Recruiters']")
page_url = recruiter.get_attribute("href")

driver.get(page_url)
time.sleep(3)

# %%
search = driver.find_element_by_xpath("//div[@class='inpWrap']//input") 
search.send_keys("Data science ")           
btn = driver.find_element_by_xpath("//button[@class='fl qsbSrch blueBtn']").click()     
time.sleep(3)

# %%
Name = []
Designation = []
Company = []
Skills = []
Location = []

# %%
for i in driver.find_elements_by_xpath("//span[@class='fl ellipsis']"):
    Name.append(i.text)
time.sleep(3)



for i in driver.find_elements_by_xpath("//span[@class='ellipsis clr']"):
    Designation.append(i.text)
time.sleep(3)


for i in driver.find_elements_by_xpath("//div[@class='vcard']//p[1]/a[2]"):
    Company.append(i.text)
time.sleep(3)
    
 
for i in driver.find_elements_by_xpath("//div[@class='hireSec highlightable']"):
    try:
        if i.text == "Not Specified": raise NoSuchElementException
        Skills.append(i.text)
    except NoSuchElementException:
        Skills.append('-')
    time.sleep(3)


for i in driver.find_elements_by_xpath("//div[@class='vcard']//p[1]//span")
    Location.append(i.text)
time.sleep(3)

# %%
df = pd.DataFrame({'Name':Name[:50],'Designation':Designation[:50],'Company Name':Company[:50],'Skills They Hire For':Skills[:50],'Location':Location[:50]})
df
# Out:
#                                              Name  \
# 0                                    Aakash Harit
# 1                            shravan Kumar Gaddam
# 2                        MARSIAN Technologies LLP
# 3                                    Anik Agrawal
# 4                                    subhas patel
# 5    Abhishek - Only Analytics Hiring - India and
# 6   Institute for Financial Management and Resear
# 7                                     Balu Ramesh
# 8                                   Asif Lucknowi
# 9                                 InstaFinancials
# 10                                Sakshi Chhikara
# 11                                 Priyanka Akiri
# 12                                Kalpana Dumpala
# 13                                        Mubarak
# 14                                 Kushal Rastogi
# 15                             Mahesh Babu Channa
# 16                                   Kapil Devang
# 17                                    Ruchi Dhote
# 18                             Sandhya Khandagale
# 19                                  Manisha Yadav
# 20                                    Riya Rajesh
# 21                           Rashmi Bhattacharjee
# 22                                  Faizan Kareem
# 23                                 Rithika dadwal
# 24                                      Shaun Rao
# 25                                  Azahar Shaikh
# 26                                          Manas
# 27                                          kumar
# 28                                   Sunil Vedula
# 29                                    Rajat Kumar
# 30                                Dhruv Dev Dubey
# 31                                         Avodha
# 32                                      Jayanth N
# 33                                    Priya Khare
# 34                                    Amit Sharma
# 35                                          Kanan
# 36                           Shashikant Chaudhary
# 37                                           Brad
# 38                                   Rutuja Pawar
# 39                            Madhusudhan Sridhar
# 40                                    Ankit Sinha
# 41                                 Gaurav Chouhan
# 42                                   Rashi Kacker
# 43                                        Ashwini
# 44                                   Balaji Kolli
# 45                                 Rajani Nagaraj
# 46                                    ROHIT Kumar
# 47                                 Amir Chowdhury
# 48                              Radha Manivasagam
# 49                                       SREEDHAR
#
#                             Designation  \
# 0                            HR Manager
# 1                     Company Recruiter
# 2                            Company HR
# 3                     Company Recruiter
# 4                           Founder CEO
# 5           Recruitment Lead Consultant
# 6                     Programme Manager
# 7                      HR Administrator
# 8                              Director
# 9                        Human Resource
# 10                 Assistant Manager HR
# 11                           HR Manager
# 12                     Executive Hiring
# 13                           Company HR
# 14                           Company HR
# 15                         HR Team Lead
# 16                           HR Manager
# 17  Senior Executive Talent Acquisition
# 18                         HR Recruiter
# 19                         HR Executive
# 20           Manager Talent Acquisition
# 21                              HR Head
# 22                           HR MANAGER
# 23                         HR Recruiter
# 24              Manager Human Resources
# 25                    Company Recruiter
# 26              Lead Talent acquisition
# 27                           Proprietor
# 28                                  CEO
# 29                          Founder CEO
# 30             Company Recruitment Head
# 31       Business Development Associate
# 32                      Project Manager
# 33                       Senior Manager
# 34                           Consultant
# 35         senior technology instructor
# 36             HR Recruiter/HR Excutive
# 37        Manager, Technical Recruiting
# 38                  Technical Recruiter
# 39                      Erp Implementer
# 40                       Head Analytics
# 41              Chief Technical Officer
# 42                   Sr Product Manager
# 43             Director Global Delivery
# 44                           Co Founder
# 45                           HR Manager
# 46                            Architect
# 47                     Managing Partner
# 48                         HR Executive
# 49               Recruitment Consultant
#
#                                       Company Name  \
# 0                             Data Science Network
# 1                    Shore Infotech India Pvt. Ltd
# 2                         MARSIAN Technologies LLP
# 3            Enerlytics Software Solutions Pvt Ltd
# 4                                  LibraryXProject
# 5       Apidel Technologies Division of Transpower
# 6                                             IFMR
# 7                      Techvantage Systems Pvt Ltd
# 8                       Weupskill- Live Wire India
# 9                 CBL Data Science Private Limited
# 10                   BIZ INFOTECNO PRIVATE LIMITED
# 11                   Infinitive Software Solutions
# 12                              Innominds Software
# 13                                        MoneyTap
# 14              QuantMagnum Technologies Pvt. Ltd.
# 15                               SocialPrachar.com
# 16                                  BISP Solutions
# 17                           Bristlecone India Ltd
# 18                 Compumatrice Multimedia Pvt Ltd
# 19                                        Easi Tax
# 20                     Novelworx Digital Solutions
# 21         AXESTRACK SOFTWARE SOLUTIONS PRIVATE...
# 22                   FirstTech Consaltants Pvt.Ltd
# 23                                Affine Analytics
# 24                              Exela Technologies
# 25                 NEAL ANALYTICS SERVICES PVT LTD
# 26      Autumn Leaf Consulting Services Private...
# 27                                         trainin
# 28                            Nanoprecise Sci Corp
# 29                  R.S Consultancy &amp; Services
# 30                                    Confidential
# 31                              Nikitha Palaparthi
# 32        Dollarbird Information Services Pvt, Ltd
# 33                          Independent Consultant
# 34                                 ASCO consulting
# 35                                         NY INST
# 36  3D India Staffing Research &amp; Consulting...
# 37                                     O.C. Tanner
# 38                                   Demand Matrix
# 39                             MADHUSUDHAN SRIDHAR
# 40                                  Suntech Global
# 41                        Strategic Consulting Lab
# 42                            Impel Labs Pvt. Ltd.
# 43                                    MRP Advisers
# 44                   Saras Solutions India Pvt Ltd
# 45                                     WildJasmine
# 46                             LNT Private Limited
# 47                                     Granular.ai
# 48                                      Techcovery
# 49     JOBSMILL BUSINESS SOLUTIONS PRIVATE LIMITED
#
#                                  Skills They Hire For  \
# 0   Classic ASP Developer, Internet Marketing Prof...
# 1   .Net, Java, Data Science, Linux Administration...
# 2   Data Science, Artificial Intelligence, Machine...
# 3   Mean Stack, javascript, angularjs, mongodb, We...
# 4   Hadoop, Spark, Digital Strategy, Data Architec...
# 5   Analytics, Business Intelligence, Business Ana...
# 6                                        Data Science
# 7   Machine Learning, algorithms, Go Getter, Compu...
# 8   Technical Training, Software Development, Pres...
# 9   Software Development, It Sales, Account Manage...
# 10  React.js, Data Science, Java, Front End, Busin...
# 11  Oracle Dba, Data Science, Data Warehousing, ET...
# 12  Qa, Ui/ux, Java Developer, Java Architect, C++...
# 13  Business Intelligence, Data Warehousing, Data ...
# 14  Office Administration, Hr Administration, tele...
# 15  Social Media, digital media maketing, seo, smm...
# 16     Big Data, Hadoop, Data Analytics, Data Science
# 17  Qlikview, Qlik Sense, Microsoft Azure, Power B...
# 18  Big Data, Data Science, Artificial Intelligenc...
# 19  Telecalling, Client Interaction, Marketing, Re...
# 20                                       Data Science
# 21  Corporate Sales, Software Development, Softwar...
# 22  Data Analytics, Data Science, Machine Learning...
# 23  Data Science, Machine Learning, Python, R, Dee...
# 24  Java, Net, Angularjs, Hr, Infrastructure, Mana...
# 25  Data Science, Artificial Intelligence, Machine...
# 26  Software Architecture, Vp Engineering, Product...
# 27  Data Science, Hadoop, Rpas, Devops, Python, Aw...
# 28  Signal Processing, Machine Learning, Neural Ne...
# 29  Web Technologies, Project Management, Software...
# 30  Server Administartion, Verilog, Vhdl, Digital ...
# 31  Ethical Hacking, Security Operations Center, S...
# 32  Data Analytics, Managed Services, Team Leading...
# 33  Data Science, Artificial Intelligence, analyti...
# 34  Machine Learning, Artificial Intelligence, Dat...
# 35  C, C++, Artificial Intelligence, Python, Php, ...
# 36  Relationship Management, Retail Sales, Private...
# 37                 Data Science, Software Engineering
# 38  Data Science, Big Data Analytics, Digital Mark...
# 39                  Data Science, Recruitment, Salary
# 40  B.Tech, Tableau, Statistics, R, Analytics, Tim...
# 41  Software Development, Business Intelligence, B...
# 42                   Data Science, Node.js, Angularjs
# 43  Data Science, Media Marketing, Resource Planni...
# 44  Data Analysis, Learning, Data Science, Compute...
# 45  Java, Hadoop, R, Machine Learning, Spark, Flum...
# 46  Software Development, Core Java, Unit Testing,...
# 47  Machine Learning, Data Science, Product Manage...
# 48  Python, Artificial Intelligence, Machine Learn...
# 49  Data Science, Machine Learning, Big Data Analy...
#
#                                          Location
# 0                                    Aakash Harit
# 1                                      HR Manager
# 2                                           Delhi
# 3                            shravan Kumar Gaddam
# 4                               Company Recruiter
# 5                        Hyderabad / Secunderabad
# 6                        MARSIAN Technologies LLP
# 7                                      Company HR
# 8                                            Pune
# 9                                    Anik Agrawal
# 10                              Company Recruiter
# 11                                      Ahmedabad
# 12                                   subhas patel
# 13                                    Founder CEO
# 14                                  UK - (london)
# 15   Abhishek - Only Analytics Hiring - India and
# 16                    Recruitment Lead Consultant
# 17                              Vadodara / Baroda
# 18  Institute for Financial Management and Resear
# 19                              Programme Manager
# 20                                        Chennai
# 21                                    Balu Ramesh
# 22                               HR Administrator
# 23                                     Trivandrum
# 24                                  Asif Lucknowi
# 25                                       Director
# 26                                         Indore
# 27                                InstaFinancials
# 28                                 Human Resource
# 29                          Bengaluru / Bangalore
# 30                                Sakshi Chhikara
# 31                           Assistant Manager HR
# 32                                     Chandigarh
# 33                                 Priyanka Akiri
# 34                                     HR Manager
# 35                                      Hyderabad
# 36                                Kalpana Dumpala
# 37                               Executive Hiring
# 38                       Hyderabad / Secunderabad
# 39                                        Mubarak
# 40                                     Company HR
# 41                          Bengaluru / Bangalore
# 42                                 Kushal Rastogi
# 43                                     Company HR
# 44                                         Mumbai
# 45                             Mahesh Babu Channa
# 46                                   HR Team Lead
# 47                       Hyderabad / Secunderabad
# 48                                   Kapil Devang
# 49                                     HR Manager

# %% [markdown]
# ### 8. Scrape the details of Highest selling novels.
# ### Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-greycompare/
# ### You have to find the following details:
# A) Book name
# B) Author name
# C) Volumes sold
# D) Publisher
# E) Genre

# %%
driver = webdriver.Chrome("chromedriver.exe")

# %%
url = "https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare"
driver.get(url)

# %%
book = []
author = []
volumes = []
publisher = []
genre = []

# %%
books = driver.find_elements_by_xpath('//table[@class="in-article sortable"]/tbody/tr/td[2]')
for i in books:
    book.append(i.text)
authors = driver.find_elements_by_xpath('//table[@class="in-article sortable"]/tbody/tr/td[3]')
for i in authors:
    author.append(i.text)
vol = driver.find_elements_by_xpath('//table[@class="in-article sortable"]/tbody/tr/td[4]')
for i in vol:
    volumes.append(i.text)
pub = driver.find_elements_by_xpath('//table[@class="in-article sortable"]/tbody/tr/td[5]')
for i in pub:
    publisher.append(i.text)
gen = driver.find_elements_by_xpath('//table[@class="in-article sortable"]/tbody/tr/td[6]')
for i in gen:
    genre.append(i.text)

# %%
Novel=pd.DataFrame({})
Novel['Book Name']=book
Novel['Author Name']= author
Novel['Volumes Sold']= volumes
Novel['Publisher']= publisher
Novel['Genre']= genre
Novel
# Out:
#                                             Book Name       Author Name  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volumes Sold        Publisher                        Genre
# 0     5,094,805       Transworld  Crime, Thriller & Adventure
# 1     4,475,152       Bloomsbury           Children's Fiction
# 2     4,200,654       Bloomsbury           Children's Fiction
# 3     4,179,479       Bloomsbury           Children's Fiction
# 4     3,758,936     Random House              Romance & Sagas
# ..          ...              ...                          ...
# 95      807,311     Random House   General & Literary Fiction
# 96      794,201          Penguin        Food & Drink: General
# 97      792,187  Scholastic Ltd.          Young Adult Fiction
# 98      791,507            Orion           Biography: General
# 99      791,095          Penguin        Food & Drink: General
#
# [100 rows x 5 columns]

# %% [markdown]
# ### 9. Scrape the details most watched tv series of all time from imdb.com.
# ### Url = https://www.imdb.com/list/ls095964455/
# ### You have to find the following details:
# A) Name
# B) Year span
# C) Genre
# D) Run time
# E) Ratings
# F) Votes

# %%
driver = webdriver.Chrome("chromedriver.exe")

# %%
url = "https://www.imdb.com/list/ls095964455/"
driver.get(url)

# %%
Name = []
Year = []
Genre = []
Runtime = []
Ratings = []
Votes = []

# %%
names = driver.find_elements_by_xpath('//h3[@class="lister-item-header"]/a')
for i in names:
    Name.append(i.text)

span = driver.find_elements_by_xpath('//span[@class="lister-item-year text-muted unbold"]')
for i in span:
    Year.append(i.text)
    
Gen = driver.find_elements_by_xpath('//span[@class="genre"]')
for i in Gen:
    Genre.append(i.text)
    
run = driver.find_elements_by_xpath('//span[@class="runtime"]')
for i in run:
    Runtime.append(i.text)
    
rate = driver.find_elements_by_xpath('//div[@class="ipl-rating-star small"]//span[2]')
for i in rate:
    Ratings.append(i.text)
    
vot = driver.find_elements_by_xpath('//div[@class="lister-item-content"]//p[4]/span[2]')
for i in vot:
    Votes.append(i.text)

# %%
IMDB = pd.DataFrame({'Movie Name':Name,'Year Span':Year,'Genre':Genre,'Run Time':Runtime,'Ratings':Ratings,'Votes':Votes})
IMDB
# Out:
#                         Movie Name    Year Span                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things     (2016– )    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)            Drama, Fantasy
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds  (2005–2020)     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#    Run Time Ratings      Votes
# 0    57 min     9.2  1,956,435
# 1    51 min     8.7    966,209
# 2    44 min     8.1    931,924
# 3    60 min     7.5    279,017
# 4    43 min     7.6    239,199
# ..      ...     ...        ...
# 95   42 min     7.5     47,793
# 96   50 min     7.8     58,517
# 97   42 min     8.1    185,721
# 98   45 min     7.1     39,312
# 99  572 min     8.6    222,009
#
# [100 rows x 6 columns]

# %% [markdown]
# ### 10. Details of Datasets from UCI machine learning repositories.
# ### Url = https://archive.ics.uci.edu/
# ### You have to find the following details:
# A) Dataset name
# B) Data type
# C) Task
# D) Attribute type
# E) No of instances
# F) No of attribute
# G) Year
#
# Note: - from the home page you have to go to the ShowAllDataset page through code

# %%
driver = webdriver.Chrome("chromedriver.exe")

# %%
url = "https://archive.ics.uci.edu/ml/index.php"
driver.get(url)

# %%
viewdataset = driver.find_element_by_xpath('//tbody/tr/td[2]/span[2]/a')
page_url = viewdataset.get_attribute('href')
driver.get(page_url)
time.sleep(5)

all_lst = driver.find_element_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[1]/tbody/tr/td[2]/p/a")  
lst_url = all_lst.get_attribute("href")           
driver.get(lst_url)
time.sleep(5)

data_url = driver.find_elements_by_xpath("//p[@class='normal']//b/a")    

urls = []     
for i in data_url:
    urls.append(i.get_attribute("href"))

# %%
Data_name = []
Data_type = []
Task = []
Attr_type = []
Instances = []
n_attributes = []
Year = []

# %%
for i in urls:
    driver.get(i)
    time.sleep(3)
    
    

    try: 
        ds_name = driver.find_element_by_xpath("//span[@class='heading']")
        Data_name.append(ds_name.text)
    except NoSuchElementException:
        Data_name.append('-')
    time.sleep(1)
    
    
    
    try:
        dtype = driver.find_element_by_xpath("//table[@border='1']//tbody/tr/td[2]")
        if dtype.text == "N/A": raise NoSuchElementException
        Data_type.append(dtype.text)
    except NoSuchElementException:
        Data_type.append('-')
    time.sleep(1)
    
    
    
    try:
        atype = driver.find_element_by_xpath("//table[@border='1']//tbody/tr[2]/td[2]")
        if atype.text == "N/A": raise NoSuchElementException
        Attr_type.append(atype.text)
    except NoSuchElementException:
        Attr_type.append('-')
    time.sleep(1)
    
    
    
    try:
        task = driver.find_element_by_xpath("//table[@border='1']//tbody/tr[3]/td[2]")
        if task.text == "N/A": raise NoSuchElementException
        Task.append(task.text)
    except NoSuchElementException:
        Task.append('-')
    time.sleep(1)
    
    
     
    try:
        inst = driver.find_element_by_xpath("//table[@border='1']//tbody/tr/td[4]")
        if inst.text == "N/A": raise NoSuchElementException
        Instances.append(inst.text)
    except NoSuchElementException:
        Instances.append('-')
    time.sleep(1)
    
    
    
    try:
        attr = driver.find_element_by_xpath("//table[@border='1']//tbody/tr[2]/td[4]")
        if attr.text == "N/A": raise NoSuchElementException
        n_attributes.append(attr.text)
    except NoSuchElementException:
        n_attributes.append('-')
    time.sleep(1)
    
    
    
    try:
        year = driver.find_element_by_xpath("//table[@border='1']//tbody/tr[2]/td[6]")
        if year.text == "N/A": raise NoSuchElementException
        Year.append(year.text[:4])
    except NoSuchElementException:
        Year.append('-')
    time.sleep(1)

# %%
UCI=pd.DataFrame({})
UCI['Data Name'] = Data_name
UCI['Data Type'] = Data_type
UCI['Task'] = Task
UCI['Attribute type'] = Attr_type
UCI['No of instance'] = Instances
UCI['No of attributes'] = n_attributes
UCI['Year'] = Year

UCI
# Out:
#                                              Data Name  \
# 0         2.4 GHZ Indoor Channel Measurements Data Set
# 1    3D Road Network (North Jutland, Denmark) Data Set
# 2                                  3W dataset Data Set
# 3                          9mers from cullpdb Data Set
# 4    : Simulated Data set of Iraqi tourism places D...
# ..                                                 ...
# 617  Youtube cookery channels viewers comments in H...
# 618     YouTube Multiview Video Games Dataset Data Set
# 619                   YouTube Spam Collection Data Set
# 620                           Z-Alizadeh Sani Data Set
# 621                                       Zoo Data Set
#
#                      Data Type                        Task  \
# 0                 Multivariate              Classification
# 1             Sequential, Text      Regression, Clustering
# 2    Multivariate, Time-Series  Classification, Clustering
# 3                   Sequential  Classification, Regression
# 4                 Multivariate  Classification, Clustering
# ..                         ...                         ...
# 617         Multivariate, Text              Classification
# 618         Multivariate, Text  Classification, Clustering
# 619                       Text              Classification
# 620                          -              Classification
# 621               Multivariate              Classification
#
#            Attribute type No of instance No of attributes  Year
# 0                    Real           7840                5  2018
# 1                    Real         434874                4  2013
# 2           Integer, Real           1984                8  2019
# 3                    Real         158716                4  2021
# 4                       -            232               16  2020
# ..                    ...            ...              ...   ...
# 617                     -           9800                3  2019
# 618         Integer, Real         120000          1000000  2013
# 619                     -           1956                5  2017
# 620         Integer, Real            303               56  2017
# 621  Categorical, Integer            101               17  1990
#
# [622 rows x 7 columns]
